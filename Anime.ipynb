# %% [markdown]
# <a href="https://colab.research.google.com/github/ItikiSatochi/Colab_Projeto/blob/main/Anime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
anime = pd.read_csv('Rank_Anime4.csv',sep=';')
display(anime)
# Out:
#                         name   type episodes           status  \
# 0          Sousou no Frieren     TV       28  Finished Airing
# 1                    Gintama     TV       51  Finished Airing
# 2        Shingeki no Kyojin      TV       10  Finished Airing
# 3          Gintama The Final  Movie        1  Finished Airing
# 4                    Gintama     TV       51  Finished Airing
# ...                      ...    ...      ...              ...
# 2008                 Chobits     TV       26  Finished Airing
# 2009     Bokutachi no Remake     TV       12  Finished Airing
# 2010         Akazukin Chacha     TV       74  Finished Airing
# 2011  Yao Shen Ji 4th Season    ONA       52  Finished Airing
# 2012   Wu Geng Ji Zhi Tianqi    ONA       42  Finished Airing
#
#                              aired    premiered                  broadcast  \
# 0     Sep 29, 2023 to Mar 22, 2024    Fall 2023     Fridays at 23:00 (JST)
# ...

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2013 non-null   object
#  1   type        2012 non-null   object
#  2   episodes    2013 non-null   object
#  3   status      2013 non-null   object
#  4   aired       2013 non-null   object
#  5   premiered   1033 non-null   object
#  6   broadcast   1033 non-null   object
#  7   producers   2012 non-null   object
#  8   licensors   2013 non-null   object
#  9   studios     2013 non-null   object
#  10  source      1363 non-null   object
#  11  genres      2012 non-null   object
#  12  duration    2013 non-null   object
#  13  rating      2012 non-null   object
#  14  score       2013 non-null   object
#  15  ranked      2013 non-null   object
#  16  popularity  2013 non-null   object
#  17  favorites   2013 non-null   object
#  18  Coluna1     1 non-null      float64
# ...

# %%
coluna = anime['producers']
coluna
# Out:
# 0       ['Aniplex', 'Dentsu', 'Shogakukan-Shueisha Pro...
# 1                       ['TV Tokyo', 'Aniplex', 'Dentsu']
# 2       ['Production I,G', 'Dentsu', 'Mainichi Broadca...
# 3       ['TV Tokyo', 'Aniplex', 'Dentsu', 'Bandai', 'W...
# 4       ['TV Tokyo', 'Aniplex', 'Dentsu', 'Trinity Sou...
#                               ...
# 2008                               ['TBS', 'Pioneer LDC']
# 2009    ['Studio Mausu', 'bilibili', 'Bushiroad Music'...
# 2010                     ['Nihon Ad Systems', 'Shueisha']
# 2011                                         ['bilibili']
# 2012                         ['Tencent Penguin Pictures']
# Name: producers, Length: 2013, dtype: object

# %%
anime['producers'] = coluna.str.replace('[', '').str.replace(']', '').str.replace("'", '')
anime
anime['licensors'] = coluna.str.replace('[', '').str.replace(']', '').str.replace("'", '')
anime
anime['genres'] = coluna.str.replace('[', '').str.replace(']', '').str.replace("'", '')
anime
anime.to_csv('anime.csv', index=False)

# %%
anime.isna().sum()
# Out:
# name             0
# type             1
# episodes         0
# status           0
# aired            0
# premiered      980
# broadcast      980
# producers        1
# licensors        1
# studios          0
# source         650
# genres           1
# duration         0
# rating           1
# score            0
# ranked           0
# popularity       0
# favorites        0
# Coluna1       2012
# license          1
# dtype: int64
